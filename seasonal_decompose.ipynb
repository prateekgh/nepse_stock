# %%
import pandas as pd
import numpy as np

# %%
import function_initial as  fn
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("stock_data.csv",low_memory=False)

# %%
df = fn.initialization(df,'NBL','2020-01-01','2022-01-01')

# %%
df.reset_index(inplace=True)

# %%
df.drop('index',axis=1)
# Out:
#           Date Symbol     LTP %Change    High     Low    Open Quantity  \
# 0   2020-01-02    NBL  266.00    0.76  268.00  263.00  265.00   25,846
# 1   2020-01-05    NBL  270.00     1.5  271.00  265.00  265.00   63,823
# 2   2020-01-06    NBL  274.00    1.48  277.00  270.00  275.00   65,947
# 3   2020-01-07    NBL  275.00    0.36  278.00  273.00  274.00   71,856
# 4   2020-01-08    NBL  273.00   -0.73  279.00  271.00  279.00   55,523
# ..         ...    ...     ...     ...     ...     ...     ...      ...
# 417 2021-12-23    NBL  350.00    0.43  355.00  344.00  354.00   85,104
# 418 2021-12-26    NBL  353.00    0.86  355.00  349.00  355.00   71,876
# 419 2021-12-27    NBL  339.00   -3.97  356.90  338.00  355.00  125,182
# 420 2021-12-28    NBL  339.00     0.0  340.00  333.00  339.00   64,076
# 421 2021-12-29    NBL  339.90    0.27  342.00  336.10  340.00   63,277
#
#           Turnover
# 0     6,839,064.00
# 1    17,116,418.00
# 2    18,016,899.00
# 3    19,781,719.00
# ...

# %%
fn.plotly_plot_line(df,'Date','LTP',df['Symbol'][1])

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

results = seasonal_decompose(x= df['LTP'],period=100)

# %%
results.plot()
